# %% [markdown]
# #### Implement the Continuous Bag of Words (CBOW) Model for the given (textual document 1)

# %%
# a.Import libraries

import numpy as np
import nltk
import re
from nltk.tokenize import word_tokenize
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ### a. Data preparation

# %%
# Download tokenizer (only first time)
nltk.download('punkt')

# Load text file
with open("CBOW.txt", "r") as file:
    text = file.read().lower()

# Remove special characters and digits
text = re.sub(r'[^a-zA-Z\s]', '', text)

# Tokenize text into words
tokens = word_tokenize(text)

print("Total tokens:", len(tokens))
print("Sample tokens:", tokens[:15])

# Create a vocabulary
vocab = sorted(set(tokens))
vocab_size = len(vocab)
print("Vocabulary size:", vocab_size)

# Create mapping of word to index
word2idx = {word: i for i, word in enumerate(vocab)}
idx2word = {i: word for word, i in word2idx.items()}
# Out:
# Total tokens: 177
# Sample tokens: ['the', 'speed', 'of', 'transmission', 'is', 'an', 'important', 'point', 'of', 'difference', 'between', 'the', 'two', 'viruses', 'influenza']
# Vocabulary size: 92
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Aashlesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### b. Generate Training Data

# %%
window_size = 2  # context window
data = []

# Create (context, target) pairs
for i in range(window_size, len(tokens) - window_size):
    context = [tokens[i - 2], tokens[i - 1], tokens[i + 1], tokens[i + 2]]
    target = tokens[i]
    data.append((context, target))

print("Total training pairs:", len(data))
print("Example pair:", data[100])
# Out:
# Total training pairs: 173
# Example pair: (['in', 'contrast', 'we', 'are'], 'while')

# %%
# Convert words to one-hot vectors
def one_hot_encode(word):
    vector = np.zeros(vocab_size)
    vector[word2idx[word]] = 1
    return vector

# Prepare training data
X = []  # inputs (contexts)
Y = []  # outputs (target)

for context, target in data:
    context_vec = np.sum([one_hot_encode(w) for w in context], axis=0)
    X.append(context_vec)
    Y.append(one_hot_encode(target))

X = np.array(X)
Y = np.array(Y)

print("Input shape:", X.shape)
print("Output shape:", Y.shape)
# Out:
# Input shape: (173, 92)
# Output shape: (173, 92)

# %% [markdown]
# ### c. Train Model

# %%
model = Sequential()
model.add(Dense(32, input_dim=vocab_size, activation='relu'))
model.add(Dense(vocab_size, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.01), metrics=['accuracy'])

history = model.fit(X, Y, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0058 - loss: 4.5182
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1618 - loss: 4.2551
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2081 - loss: 3.9644
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2081 - loss: 3.6093
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1965 - loss: 3.2999
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2601 - loss: 2.9806
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4104 - loss: 2.6313
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5145 - loss: 2.2818
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6243 - loss: 1.9295
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6821 - loss: 1.5869
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7977 - loss: 1.2775
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8902 - loss: 0.9986
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9364 - loss: 0.7778
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9538 - loss: 0.6066
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9595 - loss: 0.4772
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9653 - loss: 0.3826
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9827 - loss: 0.3029
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9884 - loss: 0.2504
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9884 - loss: 0.2084
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9884 - loss: 0.1806
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9942 - loss: 0.1579
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9884 - loss: 0.1389
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9884 - loss: 0.1228
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9942 - loss: 0.1086
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9884 - loss: 0.0988
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9942 - loss: 0.0910
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9942 - loss: 0.0836
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9942 - loss: 0.0791
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9942 - loss: 0.0715
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9942 - loss: 0.0662
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.